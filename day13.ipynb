# %% [markdown]
# <a href="https://colab.research.google.com/github/kmuhammadsin-lab/print/blob/main/day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
path="/content/students_100.csv"
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa   iq  placement
# 0           0  3.83   86          0
# 1           1  3.15  118          0
# 2           2  2.85   82          0
# 3           3  3.60   93          0
# 4           4  3.84  126          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    int64
#  3   placement   100 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa   iq  placement
# 0  3.83   86          0
# 1  3.15  118          0
# 2  2.85   82          0
# 3  3.60   93          0
# 4  3.84  126          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa   iq
# 0   3.83   86
# 1   3.15  118
# 2   2.85   82
# 3   3.60   93
# 4   3.84  126
# ..   ...  ...
# 95  3.80  117
# 96  3.77  132
# 97  2.13   92
# 98  2.96  116
# 99  2.65  126
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa   iq
# 36  3.98  127
# 66  3.81   88
# 67  3.96  133
# 17  3.58   98
# 19  3.95  133
# ..   ...  ...
# 87  3.58  116
# 13  2.43  101
# 29  3.67   90
# 39  2.51  110
# 57  2.44  110
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 36    0
# 66    0
# 67    1
# 17    1
# 19    1
#      ..
# 87    0
# 13    1
# 29    1
# 39    0
# 57    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa   iq
# 34  2.12   85
# 88  3.21   88
# 10  3.66  118
# 16  2.09   85
# 62  3.85   98
# 68  3.90   80
# 24  2.01  116
# 76  3.63   87
# 4   3.84  126
# 51  3.05  115

# %%
y_test
# Out:
# 34    1
# 88    0
# 10    1
# 16    0
# 62    1
# 68    0
# 24    0
# 76    1
# 4     0
# 51    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.57552705,  0.94485443],
#        [ 1.31213584, -1.29901502],
#        [ 1.54453985,  1.29006512],
#        [ 0.95578302, -0.72366388],
#        [ 1.52904625,  1.29006512],
#        [-0.29919865,  1.69281091],
#        [ 0.5839366 ,  0.48457352],
#        [ 0.02616697, -0.09077762],
#        [-1.2288147 , -1.75929593],
#        [ 0.98677022, -1.01133945],
#        [ 0.81634061, -0.49352342],
#        [ 1.34312304, -1.41408525],
#        [ 0.86282141,  0.65717886],
#        [ 1.20368063,  1.34760023],
#        [-1.47671231,  1.05992466],
#        [ 0.02616697, -1.06887457],
#        [ 0.19659658, -0.14831274],
#        [-0.73301947, -0.09077762],
#        [ 0.02616697,  0.88731932],
#        [-0.87246188, -0.89626922],
#        [-0.05130103, -0.32091808],
#        [ 0.28955818,  0.4270384 ],
#        [-1.3217763 , -1.52915548],
#        [-0.98091708, -1.52915548],
#        [-0.28370505, -0.20584785],
#        [-0.37666665, -0.89626922],
#        [ 1.38960384,  0.4270384 ],
# ...

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[-1.3062827 , -1.47162036],
#        [ 0.38251979, -1.29901502],
#        [ 1.07973183,  0.4270384 ],
#        [-1.3527635 , -1.47162036],
#        [ 1.37411024, -0.72366388],
#        [ 1.45157825, -1.75929593],
#        [-1.47671231,  0.31196817],
#        [ 1.03325102, -1.35655014],
#        [ 1.35861664,  0.88731932],
#        [ 0.13462218,  0.25443306]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
 y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 34    1
# 88    0
# 10    1
# 16    0
# 62    1
# 68    0
# 24    0
# 76    1
# 4     0
# 51    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >
